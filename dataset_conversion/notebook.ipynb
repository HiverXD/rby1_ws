# %%
import h5py
import numpy as np
from pathlib import Path
from lerobot.datasets.lerobot_dataset import LeRobotDataset
import logging
import shutil
import yaml
import os

with open(r'../rby1-data-collection/config.yaml', encoding='utf-8') as f: # 추후 수정
    config = yaml.safe_load(f)

root = config['demo_root']
task_name = config['conversion_task_name']
demo_root = os.path.join(root, task_name)
user_name = config['user_name']
v3_dataset_saving_root = config['v3_dataset_saving_root']

# 로깅 설정
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# --- 설정 ---
# 원본 .h5 파일이 있는 디렉토리
RAW_H5_DIR = Path(demo_root)
# 변환된 LeRobotDataset이 저장될 디렉토리 (자동 생성됨)
# LeRobotDataset은 이 디렉토리 안에 meta/, episodes/, videos/ 등의 구조를 가집니다.
OUTPUT_LEROBOT_DATASET_DIR = Path(os.path.join(v3_dataset_saving_root, task_name)) # 새로운 디렉토리 이름
os.makedirs(OUTPUT_LEROBOT_DATASET_DIR, exist_ok=True)

# LeRobotDataset의 repo_id (Hugging Face Hub에 푸시하지 않을 경우 로컬 식별자 역할)
# OUTPUT_LEROBOT_DATASET_DIR과 동일하게 설정하는 것이 일반적입니다.
REPO_ID = f"{user_name}/{task_name}"  

# 데모 에피소드의 FPS (초당 프레임 수)
DATASET_FPS = config['rec_fps']

# --- LeRobotDataset Feature 정의 ---
# .h5 파일의 데이터를 LeRobotDataset의 표준 형식에 맞춰 매핑합니다.
# 데이터 타입(dtype)과 형태(shape)는 h5 파일 구조 검사 결과를 기반으로 합니다.
# 'names' 필드는 LeRobotDataset의 메타데이터에 사용됩니다.
FEATURES = {
    # 이미지 (dtype을 'image'로 변경하고, shape를 채널 우선으로 변경)
    "observation.images.head_rgb": {
        "dtype": "image", # 'image'로 변경
        "shape": (3, 224, 224), # (channels, height, width)로 변경
        "names": ["channels", "height", "width"], # names도 변경
    },

    # 통합 상태 (state)
    "observation.state": {
        "dtype": "float32",
        "shape": (16,),# 7dof + 7dof + 2dof(gripper) # base_state(3) + gripper_state(2) + robot_position(24) = 29
        "names": None, # 필요하다면 모든 개별 상태의 이름을 연결하여 정의 가능
    },
    # 통합 액션 (action)
    "action": {
        "dtype": "float32",
        "shape": (16,), # gripper_target(2) + robot_target_joints(24) = 26
        "names": None, # 필요하다면 모든 개별 액션의 이름을 연결하여 정의 가능
    },
    # is_first, is_last, is_terminal 필드는 명시적으로 정의해야 함 (codebase_investigator 결과)
    "is_first": {"dtype": "bool", "shape": (1,), "names": None},
    "is_last": {"dtype": "bool", "shape": (1,), "names": None},
    "is_terminal": {"dtype": "bool", "shape": (1,), "names": None},
    # task와 timestamp는 FEATURES에 정의하지 않음. task는 frame_data에 문자열로, timestamp는 내부적으로 관리됨.
}

# --- 변환 함수 ---
def convert_h5_to_lerobot_dataset():
    logging.info(f"'{RAW_H5_DIR}'에서 .h5 파일 변환 시작...")
    
    # 출력 디렉토리가 이미 존재하면 삭제하고 다시 생성 (데이터 충돌 방지)
    if OUTPUT_LEROBOT_DATASET_DIR.exists():
        logging.info(f"기존 데이터셋 디렉토리 '{OUTPUT_LEROBOT_DATASET_DIR}' 삭제 중...")
        shutil.rmtree(OUTPUT_LEROBOT_DATASET_DIR)
        logging.info("삭제 완료.")

    # LeRobotDataset 생성
    lerobot_dataset = LeRobotDataset.create(
        repo_id=REPO_ID,
        root=OUTPUT_LEROBOT_DATASET_DIR, # 여기에 root 경로 명시
        robot_type="rby1",  # 사용자의 로봇 타입에 맞게 변경
        fps=DATASET_FPS,
        features=FEATURES,
        # 로컬에만 저장하고 싶다면 push_to_hub=False (기본값)
    )

    # .h5 파일들을 찾아서 순회
    h5_files = sorted(list(RAW_H5_DIR.glob("episode_*/*.h5")))
    if not h5_files:
        logging.error(f"'{RAW_H5_DIR}' 하위 episode_*/ 디렉토리에서 .h5 파일을 찾을 수 없습니다.")
        return

    for episode_idx, h5_path in enumerate(h5_files):
        logging.info(f"에피소드 {episode_idx+1}/{len(h5_files)}: '{h5_path.name}' 변환 시작...")
        try:
            with h5py.File(h5_path, 'r') as f:
                num_frames = f['head_rgb/image'].shape[0]

                for frame_idx in range(num_frames):
                    frame_data = {}

                    # is_first, is_last, is_terminal (LeRobotDataset 표준)
                    frame_data["is_first"] = np.array([frame_idx == 0], dtype=bool)
                    frame_data["is_last"] = np.array([frame_idx == num_frames - 1], dtype=bool)
                    frame_data["is_terminal"] = np.array([frame_idx == num_frames - 1], dtype=bool) # 데모의 마지막 프레임이 종료 상태라고 가정

                    # task 필드 추가 (문자열 그대로)
                    frame_data["task"] = task_name
                    
                    # 이미지 데이터 (HWC -> CHW 변환)
                    # head_rgb: (H, W, C) -> (C, H, W)
                    # frame_data["observation.images.head_rgb"] = np.transpose(f['head_rgb/image'][frame_idx], (2, 0, 1))
                    img = np.transpose(f['head_rgb/image'][frame_idx], (2, 0, 1))
                    H, W = img.shape[1], img.shape[2]  # 480, 640
                    crop_h = crop_w = 224
                    y1 = (H - crop_h) // 2
                    x1 = (W - crop_w) // 2
                    img_crop = img[:, y1:y1+crop_h, x1:x1+crop_w]  # (C,224,224)
                    frame_data["observation.images.head_rgb"] = img_crop
                    # head_depth: (H, W) -> (1, H, W) (단일 채널 추가)

                    # 상태 데이터 (float64를 float32로 변환 후 하나로 연결)
                    base_state = f['samples/base_state'][frame_idx].astype(np.float32)
                    gripper_state = f['samples/gripper_state'][frame_idx].astype(np.float32)
                    robot_position = f['samples/robot_position'][frame_idx].astype(np.float32)
                    # print("robot_position.shape:",robot_position.shape)
                    frame_data["observation.state"] = np.concatenate([robot_position[8:22], gripper_state]) # right -> left -> gripper

                    # 액션 데이터 (float64를 float32로 변환 후 하나로 연결)
                    gripper_target = f['samples/gripper_target'][frame_idx].astype(np.float32)
                    robot_target_joints = f['samples/robot_target_joints'][frame_idx].astype(np.float32)
                    # print("robot_target_joints.shape:",robot_target_joints.shape)
                    frame_data["action"] = np.concatenate([robot_target_joints[8:22], gripper_target])
                    
                    # 모든 데이터가 np.ndarray 형태인지 확인 (task 필드 제외)
                    for key, value in frame_data.items():
                        if key == "task": # 'task' 필드는 문자열 그대로 유지되어야 함
                            continue
                        if not isinstance(value, np.ndarray):
                            frame_data[key] = np.asarray(value)

                    lerobot_dataset.add_frame(frame_data)

                lerobot_dataset.save_episode()
                logging.info(f"'{h5_path.name}' 에피소드 저장 완료.")

        except Exception as e:
            logging.error(f"'{h5_path.name}' 처리 중 오류 발생: {e}", exc_info=True) # exc_info=True로 traceback 출력
            # 오류 발생 시 해당 에피소드 건너뛰기
            continue

    # 데이터셋 최종 마무리
    lerobot_dataset.finalize()
    logging.info(f"LeRobotDataset 변환 완료. '{OUTPUT_LEROBOT_DATASET_DIR}'에 저장되었습니다.")
    
    lerobot_dataset.push_to_hub(
        branch="main",
        tags=["v3.0"],
        private=False,
        allow_patterns=["*.parquet"],
    )

if __name__ == "__main__":
    convert_h5_to_lerobot_dataset()
# Out:
# 2026-02-27 16:45:48,935 - INFO - '/media/hyunjin/T7/rby1_demo/PuttingCupintotheDishV2'에서 .h5 파일 변환 시작...
# 2026-02-27 16:45:48,935 - INFO - 기존 데이터셋 디렉토리 '/media/hyunjin/T7/rby1_demo/LeRobotDataset_v3/PuttingCupintotheDishV2' 삭제 중...
# 2026-02-27 16:45:49,041 - INFO - 삭제 완료.
# 2026-02-27 16:45:49,049 - INFO - 에피소드 1/75: 'demo_0.h5' 변환 시작...
# /home/hyunjin/miniforge3/envs/lerobot/lib/python3.10/site-packages/lerobot/datasets/compute_stats.py:154: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
#   hist, _ = np.histogram(batch[:, i], bins=self._bin_edges[i])
# Map:   0%|          | 0/211 [00:00<?, ? examples/s]
# 2026-02-27 16:45:51,476 - INFO - 'demo_0.h5' 에피소드 저장 완료.
# 2026-02-27 16:45:51,477 - INFO - 에피소드 2/75: 'demo_1.h5' 변환 시작...
# Map:   0%|          | 0/178 [00:00<?, ? examples/s]
# 2026-02-27 16:45:53,601 - INFO - 'demo_1.h5' 에피소드 저장 완료.
# 2026-02-27 16:45:53,601 - INFO - 에피소드 3/75: 'demo_10.h5' 변환 시작...
# Map:   0%|          | 0/184 [00:00<?, ? examples/s]
# 2026-02-27 16:45:55,568 - INFO - 'demo_10.h5' 에피소드 저장 완료.
# 2026-02-27 16:45:55,568 - INFO - 에피소드 4/75: 'demo_11.h5' 변환 시작...
# Map:   0%|          | 0/171 [00:00<?, ? examples/s]
# 2026-02-27 16:45:57,503 - INFO - 'demo_11.h5' 에피소드 저장 완료.
# 2026-02-27 16:45:57,504 - INFO - 에피소드 5/75: 'demo_12.h5' 변환 시작...
# Map:   0%|          | 0/191 [00:00<?, ? examples/s]
# 2026-02-27 16:45:59,941 - INFO - 'demo_12.h5' 에피소드 저장 완료.
# 2026-02-27 16:45:59,941 - INFO - 에피소드 6/75: 'demo_13.h5' 변환 시작...
# Map:   0%|          | 0/215 [00:00<?, ? examples/s]
# 2026-02-27 16:46:02,429 - INFO - 'demo_13.h5' 에피소드 저장 완료.
# 2026-02-27 16:46:02,429 - INFO - 에피소드 7/75: 'demo_14.h5' 변환 시작...
# Map:   0%|          | 0/165 [00:00<?, ? examples/s]
# 2026-02-27 16:46:04,547 - INFO - 'demo_14.h5' 에피소드 저장 완료.
# 2026-02-27 16:46:04,548 - INFO - 에피소드 8/75: 'demo_15.h5' 변환 시작...
# Map:   0%|          | 0/218 [00:00<?, ? examples/s]
# 2026-02-27 16:46:07,102 - INFO - 'demo_15.h5' 에피소드 저장 완료.
# 2026-02-27 16:46:07,103 - INFO - 에피소드 9/75: 'demo_16.h5' 변환 시작...
# Map:   0%|          | 0/188 [00:00<?, ? examples/s]
# 2026-02-27 16:46:09,266 - INFO - 'demo_16.h5' 에피소드 저장 완료.
# 2026-02-27 16:46:09,267 - INFO - 에피소드 10/75: 'demo_17.h5' 변환 시작...
# Map:   0%|          | 0/197 [00:00<?, ? examples/s]
# 2026-02-27 16:46:11,463 - INFO - 'demo_17.h5' 에피소드 저장 완료.
# 2026-02-27 16:46:11,464 - INFO - 에피소드 11/75: 'demo_18.h5' 변환 시작...
# Map:   0%|          | 0/214 [00:00<?, ? examples/s]
# 2026-02-27 16:46:13,644 - INFO - 'demo_18.h5' 에피소드 저장 완료.
# 2026-02-27 16:46:13,645 - INFO - 에피소드 12/75: 'demo_19.h5' 변환 시작...
# Map:   0%|          | 0/190 [00:00<?, ? examples/s]
# 2026-02-27 16:46:15,890 - INFO - 'demo_19.h5' 에피소드 저장 완료.
# 2026-02-27 16:46:15,891 - INFO - 에피소드 13/75: 'demo_2.h5' 변환 시작...
# Map:   0%|          | 0/187 [00:00<?, ? examples/s]
# 2026-02-27 16:46:17,983 - INFO - 'demo_2.h5' 에피소드 저장 완료.
# 2026-02-27 16:46:17,983 - INFO - 에피소드 14/75: 'demo_20.h5' 변환 시작...
# Map:   0%|          | 0/261 [00:00<?, ? examples/s]
# 2026-02-27 16:46:20,728 - INFO - 'demo_20.h5' 에피소드 저장 완료.
# 2026-02-27 16:46:20,729 - INFO - 에피소드 15/75: 'demo_21.h5' 변환 시작...
# Map:   0%|          | 0/167 [00:00<?, ? examples/s]
# 2026-02-27 16:46:22,622 - INFO - 'demo_21.h5' 에피소드 저장 완료.
# 2026-02-27 16:46:22,623 - INFO - 에피소드 16/75: 'demo_22.h5' 변환 시작...
# Map:   0%|          | 0/199 [00:00<?, ? examples/s]
# 2026-02-27 16:46:24,718 - INFO - 'demo_22.h5' 에피소드 저장 완료.
# 2026-02-27 16:46:24,719 - INFO - 에피소드 17/75: 'demo_23.h5' 변환 시작...
# Map:   0%|          | 0/162 [00:00<?, ? examples/s]
# 2026-02-27 16:46:26,712 - INFO - 'demo_23.h5' 에피소드 저장 완료.
# 2026-02-27 16:46:26,713 - INFO - 에피소드 18/75: 'demo_24.h5' 변환 시작...
# Map:   0%|          | 0/217 [00:00<?, ? examples/s]
# 2026-02-27 16:46:29,206 - INFO - 'demo_24.h5' 에피소드 저장 완료.
# 2026-02-27 16:46:29,206 - INFO - 에피소드 19/75: 'demo_25.h5' 변환 시작...
# Map:   0%|          | 0/192 [00:00<?, ? examples/s]
# 2026-02-27 16:46:31,408 - INFO - 'demo_25.h5' 에피소드 저장 완료.
# 2026-02-27 16:46:31,408 - INFO - 에피소드 20/75: 'demo_26.h5' 변환 시작...
# Map:   0%|          | 0/199 [00:00<?, ? examples/s]
# 2026-02-27 16:46:33,734 - INFO - 'demo_26.h5' 에피소드 저장 완료.
# 2026-02-27 16:46:33,734 - INFO - 에피소드 21/75: 'demo_27.h5' 변환 시작...
# Map:   0%|          | 0/176 [00:00<?, ? examples/s]
# 2026-02-27 16:46:35,860 - INFO - 'demo_27.h5' 에피소드 저장 완료.
# 2026-02-27 16:46:35,861 - INFO - 에피소드 22/75: 'demo_28.h5' 변환 시작...
# Map:   0%|          | 0/171 [00:00<?, ? examples/s]
# 2026-02-27 16:46:37,698 - INFO - 'demo_28.h5' 에피소드 저장 완료.
# 2026-02-27 16:46:37,698 - INFO - 에피소드 23/75: 'demo_29.h5' 변환 시작...
# Map:   0%|          | 0/190 [00:00<?, ? examples/s]
# 2026-02-27 16:46:39,779 - INFO - 'demo_29.h5' 에피소드 저장 완료.
# 2026-02-27 16:46:39,779 - INFO - 에피소드 24/75: 'demo_3.h5' 변환 시작...
# Map:   0%|          | 0/182 [00:00<?, ? examples/s]
# 2026-02-27 16:46:41,874 - INFO - 'demo_3.h5' 에피소드 저장 완료.
# 2026-02-27 16:46:41,875 - INFO - 에피소드 25/75: 'demo_30.h5' 변환 시작...
# Map:   0%|          | 0/196 [00:00<?, ? examples/s]
# 2026-02-27 16:46:44,015 - INFO - 'demo_30.h5' 에피소드 저장 완료.
# 2026-02-27 16:46:44,016 - INFO - 에피소드 26/75: 'demo_31.h5' 변환 시작...
# Map:   0%|          | 0/161 [00:00<?, ? examples/s]
# 2026-02-27 16:46:45,811 - INFO - 'demo_31.h5' 에피소드 저장 완료.
# 2026-02-27 16:46:45,812 - INFO - 에피소드 27/75: 'demo_32.h5' 변환 시작...
# Map:   0%|          | 0/165 [00:00<?, ? examples/s]
# 2026-02-27 16:46:47,627 - INFO - 'demo_32.h5' 에피소드 저장 완료.
# 2026-02-27 16:46:47,628 - INFO - 에피소드 28/75: 'demo_33.h5' 변환 시작...
# Map:   0%|          | 0/155 [00:00<?, ? examples/s]
# 2026-02-27 16:46:49,306 - INFO - 'demo_33.h5' 에피소드 저장 완료.
# 2026-02-27 16:46:49,307 - INFO - 에피소드 29/75: 'demo_34.h5' 변환 시작...
# Map:   0%|          | 0/182 [00:00<?, ? examples/s]
# 2026-02-27 16:46:51,264 - INFO - 'demo_34.h5' 에피소드 저장 완료.
# 2026-02-27 16:46:51,264 - INFO - 에피소드 30/75: 'demo_35.h5' 변환 시작...
# Map:   0%|          | 0/198 [00:00<?, ? examples/s]
# 2026-02-27 16:46:53,198 - INFO - 'demo_35.h5' 에피소드 저장 완료.
# 2026-02-27 16:46:53,198 - INFO - 에피소드 31/75: 'demo_36.h5' 변환 시작...
# Map:   0%|          | 0/203 [00:00<?, ? examples/s]
# 2026-02-27 16:46:55,113 - INFO - 'demo_36.h5' 에피소드 저장 완료.
# 2026-02-27 16:46:55,113 - INFO - 에피소드 32/75: 'demo_37.h5' 변환 시작...
# Map:   0%|          | 0/179 [00:00<?, ? examples/s]
# 2026-02-27 16:46:57,034 - INFO - 'demo_37.h5' 에피소드 저장 완료.
# 2026-02-27 16:46:57,035 - INFO - 에피소드 33/75: 'demo_38.h5' 변환 시작...
# Map:   0%|          | 0/217 [00:00<?, ? examples/s]
# 2026-02-27 16:46:59,207 - INFO - 'demo_38.h5' 에피소드 저장 완료.
# 2026-02-27 16:46:59,208 - INFO - 에피소드 34/75: 'demo_39.h5' 변환 시작...
# Map:   0%|          | 0/240 [00:00<?, ? examples/s]
# 2026-02-27 16:47:01,794 - INFO - 'demo_39.h5' 에피소드 저장 완료.
# 2026-02-27 16:47:01,795 - INFO - 에피소드 35/75: 'demo_4.h5' 변환 시작...
# Map:   0%|          | 0/200 [00:00<?, ? examples/s]
# 2026-02-27 16:47:04,317 - INFO - 'demo_4.h5' 에피소드 저장 완료.
# 2026-02-27 16:47:04,318 - INFO - 에피소드 36/75: 'demo_40.h5' 변환 시작...
# Map:   0%|          | 0/256 [00:00<?, ? examples/s]
# 2026-02-27 16:47:07,052 - INFO - 'demo_40.h5' 에피소드 저장 완료.
# 2026-02-27 16:47:07,052 - INFO - 에피소드 37/75: 'demo_43.h5' 변환 시작...
# Map:   0%|          | 0/202 [00:00<?, ? examples/s]
# 2026-02-27 16:47:09,285 - INFO - 'demo_43.h5' 에피소드 저장 완료.
# 2026-02-27 16:47:09,285 - INFO - 에피소드 38/75: 'demo_42.h5' 변환 시작...
# Map:   0%|          | 0/237 [00:00<?, ? examples/s]
# 2026-02-27 16:47:11,563 - INFO - 'demo_42.h5' 에피소드 저장 완료.
# 2026-02-27 16:47:11,563 - INFO - 에피소드 39/75: 'demo_43.h5' 변환 시작...
# Map:   0%|          | 0/228 [00:00<?, ? examples/s]
# 2026-02-27 16:47:14,183 - INFO - 'demo_43.h5' 에피소드 저장 완료.
# 2026-02-27 16:47:14,184 - INFO - 에피소드 40/75: 'demo_44.h5' 변환 시작...
# Map:   0%|          | 0/263 [00:00<?, ? examples/s]
# 2026-02-27 16:47:17,009 - INFO - 'demo_44.h5' 에피소드 저장 완료.
# 2026-02-27 16:47:17,010 - INFO - 에피소드 41/75: 'demo_45.h5' 변환 시작...
# Map:   0%|          | 0/260 [00:00<?, ? examples/s]
# 2026-02-27 16:47:19,516 - INFO - 'demo_45.h5' 에피소드 저장 완료.
# 2026-02-27 16:47:19,516 - INFO - 에피소드 42/75: 'demo_46.h5' 변환 시작...
# Map:   0%|          | 0/217 [00:00<?, ? examples/s]
# 2026-02-27 16:47:21,841 - INFO - 'demo_46.h5' 에피소드 저장 완료.
# 2026-02-27 16:47:21,841 - INFO - 에피소드 43/75: 'demo_47.h5' 변환 시작...
# Map:   0%|          | 0/214 [00:00<?, ? examples/s]
# 2026-02-27 16:47:24,145 - INFO - 'demo_47.h5' 에피소드 저장 완료.
# 2026-02-27 16:47:24,146 - INFO - 에피소드 44/75: 'demo_48.h5' 변환 시작...
# Map:   0%|          | 0/222 [00:00<?, ? examples/s]
# 2026-02-27 16:47:26,577 - INFO - 'demo_48.h5' 에피소드 저장 완료.
# 2026-02-27 16:47:26,577 - INFO - 에피소드 45/75: 'demo_49.h5' 변환 시작...
# Map:   0%|          | 0/259 [00:00<?, ? examples/s]
# 2026-02-27 16:47:29,432 - INFO - 'demo_49.h5' 에피소드 저장 완료.
# 2026-02-27 16:47:29,433 - INFO - 에피소드 46/75: 'demo_5.h5' 변환 시작...
# Map:   0%|          | 0/198 [00:00<?, ? examples/s]
# 2026-02-27 16:47:32,067 - INFO - 'demo_5.h5' 에피소드 저장 완료.
# 2026-02-27 16:47:32,067 - INFO - 에피소드 47/75: 'demo_50.h5' 변환 시작...
# Map:   0%|          | 0/191 [00:00<?, ? examples/s]
# 2026-02-27 16:47:34,491 - INFO - 'demo_50.h5' 에피소드 저장 완료.
# 2026-02-27 16:47:34,491 - INFO - 에피소드 48/75: 'demo_51.h5' 변환 시작...
# Map:   0%|          | 0/251 [00:00<?, ? examples/s]
# 2026-02-27 16:47:37,380 - INFO - 'demo_51.h5' 에피소드 저장 완료.
# 2026-02-27 16:47:37,380 - INFO - 에피소드 49/75: 'demo_52.h5' 변환 시작...
# Map:   0%|          | 0/186 [00:00<?, ? examples/s]
# 2026-02-27 16:47:39,742 - INFO - 'demo_52.h5' 에피소드 저장 완료.
# 2026-02-27 16:47:39,742 - INFO - 에피소드 50/75: 'demo_53.h5' 변환 시작...
# Map:   0%|          | 0/244 [00:00<?, ? examples/s]
# 2026-02-27 16:47:42,478 - INFO - 'demo_53.h5' 에피소드 저장 완료.
# 2026-02-27 16:47:42,478 - INFO - 에피소드 51/75: 'demo_54.h5' 변환 시작...
# Map:   0%|          | 0/295 [00:00<?, ? examples/s]
# 2026-02-27 16:47:45,939 - INFO - 'demo_54.h5' 에피소드 저장 완료.
# 2026-02-27 16:47:45,939 - INFO - 에피소드 52/75: 'demo_55.h5' 변환 시작...
# Map:   0%|          | 0/322 [00:00<?, ? examples/s]
# 2026-02-27 16:47:49,802 - INFO - 'demo_55.h5' 에피소드 저장 완료.
# 2026-02-27 16:47:49,803 - INFO - 에피소드 53/75: 'demo_56.h5' 변환 시작...
# Map:   0%|          | 0/185 [00:00<?, ? examples/s]
# 2026-02-27 16:47:52,191 - INFO - 'demo_56.h5' 에피소드 저장 완료.
# 2026-02-27 16:47:52,191 - INFO - 에피소드 54/75: 'demo_57.h5' 변환 시작...
# Map:   0%|          | 0/209 [00:00<?, ? examples/s]
# 2026-02-27 16:47:54,752 - INFO - 'demo_57.h5' 에피소드 저장 완료.
# 2026-02-27 16:47:54,753 - INFO - 에피소드 55/75: 'demo_58.h5' 변환 시작...
# Map:   0%|          | 0/181 [00:00<?, ? examples/s]
# 2026-02-27 16:47:56,913 - INFO - 'demo_58.h5' 에피소드 저장 완료.
# 2026-02-27 16:47:56,914 - INFO - 에피소드 56/75: 'demo_59.h5' 변환 시작...
# Map:   0%|          | 0/150 [00:00<?, ? examples/s]
# 2026-02-27 16:47:59,080 - INFO - 'demo_59.h5' 에피소드 저장 완료.
# 2026-02-27 16:47:59,081 - INFO - 에피소드 57/75: 'demo_6.h5' 변환 시작...
# Map:   0%|          | 0/228 [00:00<?, ? examples/s]
# 2026-02-27 16:48:01,838 - INFO - 'demo_6.h5' 에피소드 저장 완료.
# 2026-02-27 16:48:01,839 - INFO - 에피소드 58/75: 'demo_60.h5' 변환 시작...
# Map:   0%|          | 0/126 [00:00<?, ? examples/s]
# 2026-02-27 16:48:03,669 - INFO - 'demo_60.h5' 에피소드 저장 완료.
# 2026-02-27 16:48:03,670 - INFO - 에피소드 59/75: 'demo_61.h5' 변환 시작...
# Map:   0%|          | 0/167 [00:00<?, ? examples/s]
# 2026-02-27 16:48:05,866 - INFO - 'demo_61.h5' 에피소드 저장 완료.
# 2026-02-27 16:48:05,866 - INFO - 에피소드 60/75: 'demo_62.h5' 변환 시작...
# Map:   0%|          | 0/156 [00:00<?, ? examples/s]
# 2026-02-27 16:48:08,126 - INFO - 'demo_62.h5' 에피소드 저장 완료.
# 2026-02-27 16:48:08,126 - INFO - 에피소드 61/75: 'demo_63.h5' 변환 시작...
# Map:   0%|          | 0/134 [00:00<?, ? examples/s]
# 2026-02-27 16:48:10,183 - INFO - 'demo_63.h5' 에피소드 저장 완료.
# 2026-02-27 16:48:10,184 - INFO - 에피소드 62/75: 'demo_64.h5' 변환 시작...
# Map:   0%|          | 0/151 [00:00<?, ? examples/s]
# 2026-02-27 16:48:12,219 - INFO - 'demo_64.h5' 에피소드 저장 완료.
# 2026-02-27 16:48:12,220 - INFO - 에피소드 63/75: 'demo_65.h5' 변환 시작...
# Map:   0%|          | 0/144 [00:00<?, ? examples/s]
# 2026-02-27 16:48:14,180 - INFO - 'demo_65.h5' 에피소드 저장 완료.
# 2026-02-27 16:48:14,181 - INFO - 에피소드 64/75: 'demo_66.h5' 변환 시작...
# Map:   0%|          | 0/129 [00:00<?, ? examples/s]
# 2026-02-27 16:48:16,020 - INFO - 'demo_66.h5' 에피소드 저장 완료.
# 2026-02-27 16:48:16,020 - INFO - 에피소드 65/75: 'demo_67.h5' 변환 시작...
# Map:   0%|          | 0/132 [00:00<?, ? examples/s]
# 2026-02-27 16:48:17,883 - INFO - 'demo_67.h5' 에피소드 저장 완료.
# 2026-02-27 16:48:17,883 - INFO - 에피소드 66/75: 'demo_68.h5' 변환 시작...
# Map:   0%|          | 0/134 [00:00<?, ? examples/s]
# 2026-02-27 16:48:19,801 - INFO - 'demo_68.h5' 에피소드 저장 완료.
# 2026-02-27 16:48:19,801 - INFO - 에피소드 67/75: 'demo_69.h5' 변환 시작...
# Map:   0%|          | 0/125 [00:00<?, ? examples/s]
# 2026-02-27 16:48:21,750 - INFO - 'demo_69.h5' 에피소드 저장 완료.
# 2026-02-27 16:48:21,750 - INFO - 에피소드 68/75: 'demo_7.h5' 변환 시작...
# Map:   0%|          | 0/188 [00:00<?, ? examples/s]
# 2026-02-27 16:48:24,063 - INFO - 'demo_7.h5' 에피소드 저장 완료.
# 2026-02-27 16:48:24,063 - INFO - 에피소드 69/75: 'demo_70.h5' 변환 시작...
# Map:   0%|          | 0/160 [00:00<?, ? examples/s]
# 2026-02-27 16:48:26,336 - INFO - 'demo_70.h5' 에피소드 저장 완료.
# 2026-02-27 16:48:26,337 - INFO - 에피소드 70/75: 'demo_71.h5' 변환 시작...
# Map:   0%|          | 0/174 [00:00<?, ? examples/s]
# 2026-02-27 16:48:28,705 - INFO - 'demo_71.h5' 에피소드 저장 완료.
# 2026-02-27 16:48:28,705 - INFO - 에피소드 71/75: 'demo_72.h5' 변환 시작...
# Map:   0%|          | 0/112 [00:00<?, ? examples/s]
# 2026-02-27 16:48:30,576 - INFO - 'demo_72.h5' 에피소드 저장 완료.
# 2026-02-27 16:48:30,577 - INFO - 에피소드 72/75: 'demo_73.h5' 변환 시작...
# Map:   0%|          | 0/135 [00:00<?, ? examples/s]
# 2026-02-27 16:48:32,693 - INFO - 'demo_73.h5' 에피소드 저장 완료.
# 2026-02-27 16:48:32,693 - INFO - 에피소드 73/75: 'demo_74.h5' 변환 시작...
# Map:   0%|          | 0/165 [00:00<?, ? examples/s]
# 2026-02-27 16:48:35,086 - INFO - 'demo_74.h5' 에피소드 저장 완료.
# 2026-02-27 16:48:35,087 - INFO - 에피소드 74/75: 'demo_8.h5' 변환 시작...
# Map:   0%|          | 0/168 [00:00<?, ? examples/s]
# 2026-02-27 16:48:37,285 - INFO - 'demo_8.h5' 에피소드 저장 완료.
# 2026-02-27 16:48:37,286 - INFO - 에피소드 75/75: 'demo_9.h5' 변환 시작...
# Map:   0%|          | 0/191 [00:00<?, ? examples/s]
# 2026-02-27 16:48:39,846 - INFO - 'demo_9.h5' 에피소드 저장 완료.
# 2026-02-27 16:48:39,852 - INFO - LeRobotDataset 변환 완료. '/media/hyunjin/T7/rby1_demo/LeRobotDataset_v3/PuttingCupintotheDishV2'에 저장되었습니다.
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# No files have been modified since last commit. Skipping to prevent empty commit.
# 2026-02-27 16:48:45,049 - WARNING - No files have been modified since last commit. Skipping to prevent empty commit.
